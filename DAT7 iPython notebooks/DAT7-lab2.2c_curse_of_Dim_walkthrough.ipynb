# %% [markdown]
# ## Curse of dimensionality walkthrough
# This notebook will help to develop intuitions about a phenomena called the "curse of dimensionality"
# - As dimension number increases, traditional intuitions about "closeness" and "volume" associated with 1, 2, and 3 dimensions tend to break down
# - One way to think of this is that as dimensionality increases, distances functions seem to lose their ability to distinguish closeness.
# 	- The practical effect of this is that the distances between sample points seem to all become equally far apart as dimension increases.
# - A second practical result of the curse of dimensionality is that for high dimension, "most of the volume" of a high dimensional figure (e.g. a hyper-cube) will be located at the margins.
# - Specifically, in this exercise, we will walk through a sequence of "hyper-cubes" of increasing dimensionality, removing a doughnut hole with 90% of the length.
# 	- We will see that even though we are removing doughnut holes that have 90% of the edge length, as **d** grows large, most of the volume will lie in the margins.

# %%
# prep material
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1-dim case
# - We begin with a 1-unit hypercube in 1 dimension (i.e a line), and then remove a .9 length segment in the middle.

# %%
# set the dimension and edge length
d = 1
edgeLen = 1
marginRatio = .1

TotVolume = edgeLen**d 

HoleLen = edgeLen*(1-marginRatio)

HoleVolume = HoleLen**d 

print "When dimension = " + str(d) + " and the margins are " + str(marginRatio*100) + "% of the total edge length:" 
print "   Total volume = " + str(TotVolume)
print "   Hole volume = " + str(HoleVolume)
print "   So as a ratio this means " + str(100*(TotVolume - HoleVolume)/TotVolume) + "% of the volume is in the margins."
# Out:
# When dimension = 1 and the margins are 10.0% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.9
#    So as a ratio this means 10.0% of the volume is in the margins.

# %% [markdown]
# ### Generalize for d > 1
# Lets build a custom function to do this for arbitrary of dimensions

# %%
def hyperMarginRatio(d = 1, marginRatio = .1, edgeLen = 1):
    TotVolume = edgeLen**d 

    HoleLen = edgeLen*(1-marginRatio)
    HoleVolume = HoleLen**d 

    marginRatio = (TotVolume - HoleVolume)/TotVolume
    
    print "When dimension = " + str(d) + " and the margins are " + str(marginRatio*100) + "% of the total edge length:" 
    print "   Total volume = " + str(TotVolume)
    print "   Hole volume = " + str(HoleVolume)
    print "   So as a ratio,"
    print str(100*marginRatio) + "% of the volume is in the margins."
    print ""
    return marginRatio

# %% [markdown]
# ### 2-dim case

# %%
d2 = hyperMarginRatio(d = 2)
# Out:
# When dimension = 2 and the margins are 19.0% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.81
#    So as a ratio,
# 19.0% of the volume is in the margins.

# %% [markdown]
# ### n-dim case
#
# So for the 2 dimension case, we see that around 19% is in the margins.
# Now lets loop through n = 1,2,3,... to see how this ratio increases with dimension number:

# %%
maxD = 50
marginRatio = .10


marginRatios = []
X = range(1,maxD+1)

for d in X:
    appenders = round(hyperMarginRatio(d, marginRatio = marginRatio), 2)
    marginRatios.append(appenders)

print marginRatios
# Out:
# When dimension = 1 and the margins are 10.0% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.9
#    So as a ratio,
# 10.0% of the volume is in the margins.
#
# When dimension = 2 and the margins are 19.0% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.81
#    So as a ratio,
# 19.0% of the volume is in the margins.
#
# When dimension = 3 and the margins are 27.1% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.729
#    So as a ratio,
# 27.1% of the volume is in the margins.
#
# When dimension = 4 and the margins are 34.39% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.6561
#    So as a ratio,
# 34.39% of the volume is in the margins.
#
# When dimension = 5 and the margins are 40.951% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.59049
#    So as a ratio,
# 40.951% of the volume is in the margins.
#
# When dimension = 6 and the margins are 46.8559% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.531441
#    So as a ratio,
# 46.8559% of the volume is in the margins.
#
# When dimension = 7 and the margins are 52.17031% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.4782969
#    So as a ratio,
# 52.17031% of the volume is in the margins.
#
# When dimension = 8 and the margins are 56.953279% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.43046721
#    So as a ratio,
# 56.953279% of the volume is in the margins.
#
# When dimension = 9 and the margins are 61.2579511% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.387420489
#    So as a ratio,
# 61.2579511% of the volume is in the margins.
#
# When dimension = 10 and the margins are 65.13215599% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.3486784401
#    So as a ratio,
# 65.13215599% of the volume is in the margins.
#
# When dimension = 11 and the margins are 68.618940391% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.31381059609
#    So as a ratio,
# 68.618940391% of the volume is in the margins.
#
# When dimension = 12 and the margins are 71.7570463519% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.282429536481
#    So as a ratio,
# 71.7570463519% of the volume is in the margins.
#
# When dimension = 13 and the margins are 74.5813417167% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.254186582833
#    So as a ratio,
# 74.5813417167% of the volume is in the margins.
#
# When dimension = 14 and the margins are 77.123207545% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.22876792455
#    So as a ratio,
# 77.123207545% of the volume is in the margins.
#
# When dimension = 15 and the margins are 79.4108867905% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.205891132095
#    So as a ratio,
# 79.4108867905% of the volume is in the margins.
#
# When dimension = 16 and the margins are 81.4697981115% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.185302018885
#    So as a ratio,
# 81.4697981115% of the volume is in the margins.
#
# When dimension = 17 and the margins are 83.3228183003% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.166771816997
#    So as a ratio,
# 83.3228183003% of the volume is in the margins.
#
# When dimension = 18 and the margins are 84.9905364703% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.150094635297
#    So as a ratio,
# 84.9905364703% of the volume is in the margins.
#
# When dimension = 19 and the margins are 86.4914828233% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.135085171767
#    So as a ratio,
# 86.4914828233% of the volume is in the margins.
#
# When dimension = 20 and the margins are 87.8423345409% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.121576654591
#    So as a ratio,
# 87.8423345409% of the volume is in the margins.
#
# When dimension = 21 and the margins are 89.0581010868% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.109418989132
#    So as a ratio,
# 89.0581010868% of the volume is in the margins.
#
# When dimension = 22 and the margins are 90.1522909782% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0984770902184
#    So as a ratio,
# 90.1522909782% of the volume is in the margins.
#
# When dimension = 23 and the margins are 91.1370618803% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0886293811965
#    So as a ratio,
# 91.1370618803% of the volume is in the margins.
#
# When dimension = 24 and the margins are 92.0233556923% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0797664430769
#    So as a ratio,
# 92.0233556923% of the volume is in the margins.
#
# When dimension = 25 and the margins are 92.8210201231% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0717897987692
#    So as a ratio,
# 92.8210201231% of the volume is in the margins.
#
# When dimension = 26 and the margins are 93.5389181108% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0646108188923
#    So as a ratio,
# 93.5389181108% of the volume is in the margins.
#
# When dimension = 27 and the margins are 94.1850262997% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.058149737003
#    So as a ratio,
# 94.1850262997% of the volume is in the margins.
#
# When dimension = 28 and the margins are 94.7665236697% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0523347633027
#    So as a ratio,
# 94.7665236697% of the volume is in the margins.
#
# When dimension = 29 and the margins are 95.2898713028% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0471012869725
#    So as a ratio,
# 95.2898713028% of the volume is in the margins.
#
# When dimension = 30 and the margins are 95.7608841725% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0423911582752
#    So as a ratio,
# 95.7608841725% of the volume is in the margins.
#
# When dimension = 31 and the margins are 96.1847957552% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0381520424477
#    So as a ratio,
# 96.1847957552% of the volume is in the margins.
#
# When dimension = 32 and the margins are 96.5663161797% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0343368382029
#    So as a ratio,
# 96.5663161797% of the volume is in the margins.
#
# When dimension = 33 and the margins are 96.9096845617% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0309031543826
#    So as a ratio,
# 96.9096845617% of the volume is in the margins.
#
# When dimension = 34 and the margins are 97.2187161056% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0278128389444
#    So as a ratio,
# 97.2187161056% of the volume is in the margins.
#
# When dimension = 35 and the margins are 97.496844495% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0250315550499
#    So as a ratio,
# 97.496844495% of the volume is in the margins.
#
# When dimension = 36 and the margins are 97.7471600455% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0225283995449
#    So as a ratio,
# 97.7471600455% of the volume is in the margins.
#
# When dimension = 37 and the margins are 97.972444041% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0202755595904
#    So as a ratio,
# 97.972444041% of the volume is in the margins.
#
# When dimension = 38 and the margins are 98.1751996369% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0182480036314
#    So as a ratio,
# 98.1751996369% of the volume is in the margins.
#
# When dimension = 39 and the margins are 98.3576796732% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0164232032683
#    So as a ratio,
# 98.3576796732% of the volume is in the margins.
#
# When dimension = 40 and the margins are 98.5219117059% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0147808829414
#    So as a ratio,
# 98.5219117059% of the volume is in the margins.
#
# When dimension = 41 and the margins are 98.6697205353% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0133027946473
#    So as a ratio,
# 98.6697205353% of the volume is in the margins.
#
# When dimension = 42 and the margins are 98.8027484817% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0119725151826
#    So as a ratio,
# 98.8027484817% of the volume is in the margins.
#
# When dimension = 43 and the margins are 98.9224736336% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.0107752636643
#    So as a ratio,
# 98.9224736336% of the volume is in the margins.
#
# When dimension = 44 and the margins are 99.0302262702% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.00969773729788
#    So as a ratio,
# 99.0302262702% of the volume is in the margins.
#
# When dimension = 45 and the margins are 99.1272036432% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.00872796356809
#    So as a ratio,
# 99.1272036432% of the volume is in the margins.
#
# When dimension = 46 and the margins are 99.2144832789% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.00785516721128
#    So as a ratio,
# 99.2144832789% of the volume is in the margins.
#
# When dimension = 47 and the margins are 99.293034951% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.00706965049015
#    So as a ratio,
# 99.293034951% of the volume is in the margins.
#
# When dimension = 48 and the margins are 99.3637314559% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.00636268544114
#    So as a ratio,
# 99.3637314559% of the volume is in the margins.
#
# When dimension = 49 and the margins are 99.4273583103% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.00572641689702
#    So as a ratio,
# 99.4273583103% of the volume is in the margins.
#
# When dimension = 50 and the margins are 99.4846224793% of the total edge length:
#    Total volume = 1
#    Hole volume = 0.00515377520732
#    So as a ratio,
# 99.4846224793% of the volume is in the margins.
#
# [0.1, 0.19, 0.27, 0.34, 0.41, 0.47, 0.52, 0.57, 0.61, 0.65, 0.69, 0.72, 0.75, 0.77, 0.79, 0.81, 0.83, 0.85, 0.86, 0.88, 0.89, 0.9, 0.91, 0.92, 0.93, 0.94, 0.94, 0.95, 0.95, 0.96, 0.96, 0.97, 0.97, 0.97, 0.97, 0.98, 0.98, 0.98, 0.98, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99]

# %%
plt.plot(X,marginRatios)
plt.title('Ratio of margins volume as a function of dimension')

# %% [markdown]
# As we can see, when the margins are constructed by removing 90% of the edge length,
# - The majority of the volume remains in the margin region of the remainder of the hyper-cube for dimensionality over d = 6.
# - And over 99% of the volume remains in the 10% margin region for d > 44.

# %%
### Exercise:
# Develop your intuitions about high dimensional volumes by using our custom function for other edge margin values (e.g.  instead of .1 try .05, or .01…) how does this effect the curve?
